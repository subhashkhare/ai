# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

#list of stopwords in library

en_stopwords = stopwords.words('english')
print(en_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
prompt = 'Learning a little each day adds up. Research shows that students who make learning a habit are more likely to reach their goals. Set time aside to learn and get reminders using your learning scheduler.'

print(' '.join([word for word in prompt.split() if word not in en_stopwords]))
# Out:
# Learning little day adds up. Research shows students make learning habit likely reach goals. Set time aside learn get reminders using learning scheduler.

# %% [markdown]
# ## Tokenization
#
# ### used removed stopwords, change case then word tokeize

# %%
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize

sentance = 'Learning a little each day adds up. Research shows that students who make learning a habit are more likely to reach their goals. Set time aside to learn and get reminders using your learning scheduler.'

#sent_tokenize(sentance)
print('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
word_tokenize(' '.join([word for word in prompt.split() if word not in en_stopwords]).lower())
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\khare\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# ['learning',
#  'little',
#  'day',
#  'adds',
#  'up',
#  '.',
#  'research',
#  'shows',
#  'students',
#  'make',
#  'learning',
#  'habit',
#  'likely',
#  'reach',
#  'goals',
#  '.',
#  'set',
#  'time',
#  'aside',
#  'learn',
#  'get',
#  'reminders',
#  'using',
#  'learning',
#  'scheduler',
#  '.']

# %%
sent_tokenize(sentance)
# Out:
# ['Learning a little each day adds up.',
#  'Research shows that students who make learning a habit are more likely to reach their goals.',
#  'Set time aside to learn and get reminders using your learning scheduler.']

# %% [markdown]
# # N-grams

# %%
import nltk
import pandas as pd
import matplotlib as plt

# %%
tokens = ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']
print(tokens)
# Out:
# ['the', 'rise', 'of', 'artificial', 'intelligence', 'has', 'led', 'to', 'significant', 'advancements', 'in', 'natural', 'language', 'processing', 'computer', 'vision', 'and', 'other', 'fields', 'machine', 'learning', 'algorithms', 'are', 'becoming', 'more', 'sophisticated', 'enabling', 'computers', 'to', 'perform', 'complex', 'tasks', 'that', 'were', 'once', 'thought', 'to', 'be', 'the', 'exclusive', 'domain', 'of', 'humans', 'with', 'the', 'advent', 'of', 'deep', 'learning', 'neural', 'networks', 'have', 'become', 'even', 'more', 'powerful', 'capable', 'of', 'processing', 'vast', 'amounts', 'of', 'data', 'and', 'learning', 'from', 'it', 'in', 'ways', 'that', 'were', 'not', 'possible', 'before', 'as', 'a', 'result', 'ai', 'is', 'increasingly', 'being', 'used', 'in', 'a', 'wide', 'range', 'of', 'industries', 'from', 'healthcare', 'to', 'finance', 'to', 'transportation', 'and', 'its', 'impact', 'is', 'only', 'set', 'to', 'grow', 'in', 'the', 'years', 'to', 'come']

# %%
unigrams = pd.Series(nltk.ngrams(tokens, 1)).value_counts()
print(unigrams[:])
# Out:
# (to,)          7
# (of,)          6
# (the,)         4
# (in,)          4
# (learning,)    3
#               ..
# (humans,)      1
# (rise,)        1
# (advent,)      1
# (deep,)        1
# (come,)        1
# Name: count, Length: 79, dtype: int64

# %%
unigrams[:10].plot.bar(color='aqua', width=.5, figsize=(12,8)) 
plt.pyplot.title('Top 10 tokens')
# Out:
# Text(0.5, 1.0, 'Top 10 tokens')

# %%
bigrams = pd.Series(nltk.ngrams(tokens, 2)).value_counts()
print(bigrams)
# Out:
# (that, were)             2
# (the, rise)              1
# (increasingly, being)    1
# (ai, is)                 1
# (result, ai)             1
#                         ..
# (tasks, that)            1
# (complex, tasks)         1
# (perform, complex)       1
# (to, perform)            1
# (to, come)               1
# Name: count, Length: 105, dtype: int64

# %%
bigrams[:10].sort_values().plot.barh(color='red', width=.5, figsize=(12,8)) 
plt.pyplot.title('Top 10 bitokens')
# Out:
# Text(0.5, 1.0, 'Top 10 bitokens')
